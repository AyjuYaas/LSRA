# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel("./E Commerce Dataset.xlsx", sheet_name="E Comm")
display(data.columns)
data['Churn'] = data['Churn'].replace({0:"No", 1:"Yes"})
# Out:
# Index(['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
# Creating Tenure Groups
bins = [0, 18, 30, np.inf]
labels = ['0-18', '18-30', '30+']
data['TenureRange'] = pd.cut(data['Tenure'], bins = bins, labels = labels, right = False, include_lowest = True)

plt.figure(figsize=(6,4))
ax = sns.countplot(data = data, x = 'TenureRange', hue = 'Churn', palette = 'viridis')

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')

plt.xlabel('Tenure(months)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='PreferredLoginDevice', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')

plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='CityTier', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')

plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.kdeplot(
    data=data, 
    x='WarehouseToHome', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title
plt.xlabel("WarehouseToHome")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='PreferredPaymentMode', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')

plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='Gender', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))

# KDE plot for 'TotalCharges' by 'Churn' categories
sns.kdeplot(
    data=data, 
    x='HourSpendOnApp', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title

plt.xlabel("HourSpendOnApp")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='NumberOfDeviceRegistered', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='PreferedOrderCat', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='SatisfactionScore', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x='MaritalStatus', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x='NumberOfAddress', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.countplot(x='Complain', hue='Churn', palette='viridis', data=data)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height), 
                    ha = 'center', va = 'baseline', 
                    xytext = (0, 3), weight = 'bold',
                    textcoords = 'offset points')
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4)) # Set figure size

# KDE plot for 'TotalCharges' by 'Churn' categories
sns.kdeplot(
    data=data, 
    x='OrderAmountHikeFromlastYear', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title

plt.xlabel("OrderAmountHikeFromlastYear")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,4)) # Set figure size

# KDE plot for 'TotalCharges' by 'Churn' categories
sns.kdeplot(
    data=data, 
    x='CouponUsed', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title

plt.xlabel("CouponUsed")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,4)) # Set figure size

# KDE plot for 'TotalCharges' by 'Churn' categories
sns.kdeplot(
    data=data, 
    x='OrderCount', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title

plt.xlabel("OrderCount")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,4))# Set figure size

# KDE plot for 'TotalCharges' by 'Churn' categories
sns.kdeplot(
    data=data, 
    x='DaySinceLastOrder', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title

plt.xlabel("DaySinceLastOrder")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,4))# Set figure size

# KDE plot for 'TotalCharges' by 'Churn' categories
sns.kdeplot(
    data=data, 
    x='CashbackAmount', 
    hue='Churn', 
    fill=True, 
    # common_norm=False,  # Normalize density separately for each category
    palette=['skyblue', 'pink']  # Colors for categories
)

# Adding labels and title

plt.xlabel("CashbackAmount")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
